# %% [markdown]
# # Understanding `torch`
#
# This is just a quick notebook summarizing how to set ourselves up for working with `torch` in Google Colab.

# %% [markdown]
# ## Setup
#
# ### Accessing GPU
#
# A benefit of Google Colab is that it provides free GPU access, which in the context of training the NAVAR model will be helpful. To access GPU, go to *Runtime* > *Change runtime type* and select *GPU*.
#
# ### Mounting your drive
#
# Before getting started, let's first mount our drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# This next line may need to be adapted depending how you've set up your folders
# on Google Drive. 
# %cd drive/MyDrive/navar
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/navar

# %% [markdown]
# Next, we'll import the R Magic to be able to run R cells:

# %%
# %load_ext rpy2.ipython

# %% [markdown]
# Next we will install and load `torch` and `torchvision`. This may take a few minutes.

# %%
# %%R
# install.packages("torch")
# devtools::install_github("mlverse/torchvision")
# library(torch)
# library(torchvision)
# Out:
# R[write to console]: Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/torch_0.3.0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1297809 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %% [markdown]
# ## A simple example

# %%
# %%R
# train_ds <- kmnist_dataset(
#   ".",
#   download = TRUE,
#   train = TRUE,
#   transform = transform_to_tensor
# )
#
# test_ds <- kmnist_dataset(
#   ".",
#   download = TRUE,
#   train = FALSE,
#   transform = transform_to_tensor
# )
#
# train_dl <- dataloader(train_ds, batch_size = 32, shuffle = TRUE)
# test_dl <- dataloader(test_ds, batch_size = 32)
# Out:
# R[write to console]: Error in kmnist_dataset(".", download = TRUE, train = TRUE, transform = transform_to_tensor) :
#   could not find function "kmnist_dataset"
# Error in kmnist_dataset(".", download = TRUE, train = TRUE, transform = transform_to_tensor) :
#   could not find function "kmnist_dataset"
