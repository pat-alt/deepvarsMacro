# %%
# %pip install -r requirements.txt
# Out:
# ...
#      |████████████
#      |███████████████████████▏        | 580.9 MB 74 kB/s eta 0:50:03     |███████████████████████         | 580.5 MB 33 kB/s eta 1:50:02     |███████████████████████         | 580.7 MB 35 kB/s eta 1:44:30Note: you may need to restart the kernel to use updated packages.

# %%
# %python run_causeme_experiments.py --experiment experiment_name
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).
